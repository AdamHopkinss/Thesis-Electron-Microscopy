# %% [markdown]
# ### DG with SIAC Experiments
#
# This notebook is used to verify the DG + SIAC reconstruction pipeline and to test admissible parameter configurations. It also serves to visually inspect a small number of reconstructed images and corresponding error behavior.
#
# The purpose is to validate correctness, identify meaningful parameter ranges (e.g., DG degree, polynomial reproduction order, and B-spline order), and determine which configurations are suitable for inclusion in the Monte Carlo (MC) study.
#
# This notebook acts as a preamble to the MC experiments, where only validated and well-behaved parameter combinations are carried forward.

# %%
import numpy as np
import pandas as pd
import odl
import matplotlib.pyplot as plt
import sys
sys.path.append("../..")

# %%
from src.transforms import nodal_image_to_dg
from src.evaluation import eval_dg_on_img_grid
from src.siac_modal import apply_siac_modal_dg_2d
from src.utils import _to_numpy

from src.tomo import(
    make_space_2d, 
    shepp_logan_2d, 
    parallel_geom_2d, 
    ray_transform_2d, 
    reconstruct_fbp, 
    add_relative_gaussian_noise, 
    multi_disk_phantom_2d, 
)

from src.metrics import(
    rel_l2_err, 
    ssim, 
    gradient_weighted_ssim, 
    eval_metrics, 
    build_metrics_table
)

from src.plotting_helpers import (
    plot_img, 
    plot_img_zoom, 
    save_image_w_zoom, 
    plot_param_heatmap_single_run
)

# %% [markdown]
# ### 2D space and Phantom

# %%
### Create the reconstruction space and phantom ###

xmin, xmax, ymin, ymax = -20, 20, -20, 20
Nx, Ny = 128, 128

space = make_space_2d(Nx=Nx, Ny=Ny, domain=[xmin, xmax, ymin, ymax])

# Need to change: mask_keep_largest argument for build_metrics_table to False unless using Shepp Logan, then True
phantom = shepp_logan_2d(space)
# phantom = multi_disk_phantom_2d(space)

# phantom_name = "multi_disc"
phantom_name = "shepp_logan"

phantom_np = phantom.asarray()

# Full angular coverage (mimic CT)
angular_coverage=(-90,90)
step = 3                    # angular resolution (3 degrees per step)

# detector half-width should be at least the half-diagonal of the reconstruction box
r = np.sqrt((0.5*(xmax - xmin))**2 + (0.5*(ymax - ymin))**2)
det_range = (-r, r)

det_count = int(np.ceil(1.5 * np.sqrt(Nx**2 + Ny**2)))

geom = parallel_geom_2d(angular_coverage=angular_coverage, step=step, 
                        det_range=det_range, det_count=det_count)
A = ray_transform_2d(space, geom)
data_space = A.range

sinogram = A(phantom)

# testing with 10% Noise here
sino_noisy = add_relative_gaussian_noise(sinogram, rel_level=0.1)

plot_img(img=phantom, title="Original Phantom")
plot_img_zoom(img=phantom, title="Original Phantom (Zoomed)")

save_image_w_zoom(img=phantom, save_path=f"figures/phantom_{phantom_name}.pdf")
# Out:
# /home/ahopkins/KTH_TTMAM/MEX/odl_xray/venv/lib/python3.10/site-packages/odl/util/utility.py:1398: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_requirements
# ('figures/phantom_shepp_logan.pdf', 'figures/phantom_shepp_logan_zoom.pdf')

# %% [markdown]
# ### For the Nodal-->Modal approach
#
#
# Since the image space is $100\times 100$, we require the relationships
# $$
#     \mathrm{DOF}_x = K_x(p+1), \quad \mathrm{DOF}_y = K_y(p+1)
# $$
# to hold. Where $(\mathrm{DOF}_x, \mathrm{DOF}_y) = (100,100)$, $K_j$ for $j\in \{x,y\}$ denotes the number of elements in the $x-$ and $y-$ directions, and $p$ is the polynomial degree of the modal basis.
#
# Since $100$ has the prime factorization
# $$
#     100 = 2^2 \cdot 5^2
# $$
#
#
# the constraint above restricts the possible element-degree pairs $(K,p)$.Some admissible combinations are
# 1. $(K,p) = (100,0)$
# 2. $(K,p) = (50,1)$
# 3. $(K,p) = (25,3)$
# 4. $(K,p) = (20,4)$
# 5. $(K,p) = (10,9)$
#
# and others obtained from the divisors of $100$.
#
# In practice, we only consider the first few cases. The last case is not well suited, since such high polynomial degrees are unnecessary for the present problem and would lead to very large elements.

# %%
#### Testing on the noiseless phantom ####
xmin, ymin = space.min_pt
xmax, ymax = space.max_pt

xlim = (xmin, xmax)
ylim = (ymin, ymax)

# Admissible degrees: 0, 1, 3, 4, 9 (if wrong, will be internally fixed by nodal_image_to_dg
p = 1
order = p + 1

# Postprocessor
moments = 2
BSorder = 2

# nodal interpretation: nodal --> modal transform
dg = nodal_image_to_dg(recon=phantom, xlim=xlim, ylim=ylim, p=p)

# immediate evaluation
U_noiseless = eval_dg_on_img_grid(dg=dg)

# Postprocessor
Ustar_noiseless = apply_siac_modal_dg_2d(dg=dg, moments=moments, BSorder=BSorder)

plot_img(img=U_noiseless, title=f"DG evaluation (p={p})")
plot_img(img=Ustar_noiseless, title=f"SIAC evaluation (r={moments}, n={BSorder})")

plot_img_zoom(img=U_noiseless, title=f"DG evaluation (p={p}) (zoom)")
plot_img_zoom(img=Ustar_noiseless, title=f"SIAC evaluation (r={moments}, n={BSorder}) (zoom)")
# Out:
# (<Figure size 500x500 with 1 Axes>,
#  <Axes: title={'center': 'SIAC evaluation (r=2, n=2) (zoom)'}>)

# %%
### Create a Noisy phantom using the FBP ###
filter_used = "Ram-Lak"
fbp_ramp = reconstruct_fbp(sino_noisy, A, filter_name=filter_used)
### Create the Hann windowed FBP ###
fbp_hann = reconstruct_fbp(sino_noisy, A, filter_name="Hann")

# %%
# Admissible degrees: 0, 1, 3, 4, 9 (if wrong, will be internally fixed by nodal_image_to_dg
p = 3
order = p + 1

# Postprocessor
moments = 6
BSorder = 4

# nodal interpretation: nodal --> modal transform
dg = nodal_image_to_dg(recon=fbp_ramp, xlim=xlim, ylim=ylim, p=p)

# immediate evaluation
U = eval_dg_on_img_grid(dg=dg)

# Postprocessor
Ustar = apply_siac_modal_dg_2d(dg=dg, moments=moments, BSorder=BSorder)
plot_img(img=fbp_ramp, title=f"FBP ({filter_used})")
plot_img(img=U, title=f"DG evaluation (p={p})")
plot_img(img=Ustar, title=f"SIAC-DG (p={p}, r+1={moments+1}, n={BSorder})")

plot_img_zoom(img=fbp_ramp, title=f"FBP ({filter_used}) (zoom)")
plot_img_zoom(img=U, title=f"DG evaluation (p={p}) (zoom)")
plot_img_zoom(img=Ustar, title=f"SIAC-DG (p={p}, r+1={moments+1}, n={BSorder}) (zoom)")

save_image_w_zoom(img=fbp_ramp, save_path=f"figures/{phantom_name}_fbp_ram_lak.pdf")
save_image_w_zoom(img=fbp_hann, save_path=f"figures/{phantom_name}_fbp_hann.pdf")
save_image_w_zoom(img=Ustar, save_path=f"figures/{phantom_name}_siac_dg_p{p}r{moments+1}n{BSorder}.pdf")
# Out:
# ('figures/shepp_logan_siac_dg_p3r7n4.pdf',
#  'figures/shepp_logan_siac_dg_p3r7n4_zoom.pdf')

# %% [markdown]
# ### Comparison with the Hann filter

# %%
plot_img(img=fbp_hann, title="FBP (Hann)")
plot_img(img=Ustar, title=f"SIAC evaluation (p={p}, r+1={moments+1}, n={BSorder})")

plot_img_zoom(img=fbp_hann, title=f"FBP (Hann) (zoom)")
plot_img_zoom(img=Ustar, title=f"SIAC evaluation (p={p}, r+1={moments+1}, n={BSorder}) (zoom)")

err_hann = fbp_hann.asarray() - phantom_np
err_siac = Ustar - phantom_np

vmin = min(err_hann.min(), err_siac.min())
vmax = max(err_hann.max(), err_siac.max())
plot_img(img=err_hann, title="Error: Hann - Exact", vmin=vmin, vmax=vmax)
plot_img(img=err_siac, title="Error: SIAC - Exact", vmin=vmin, vmax=vmax)
# Out:
# (<Figure size 500x500 with 1 Axes>,
#  <Axes: title={'center': 'Error: SIAC - Exact'}>)

# %%
cases = {
    "FBP-ramp": {
        "image": fbp_ramp.asarray(),
    },
    "FBP-Hann": {
        "image": fbp_hann.asarray(),
        "reference": fbp_ramp.asarray(),
    },
    "SIAC(FBP-ramp)": {
        "image": Ustar,
        "reference": fbp_ramp.asarray(),
    },
}
dx, dy = space.cell_sides


df = build_metrics_table(
    cases,
    truth=phantom_np,
    dx=dx,
    dy=dy,
    hf_frac=0.6,
    data_range=1.0,
    compute_reference_metrics=False, 
    mask_keep_largest=False     # False if not shepp_logan
)

df
# Out:
#              name  rel_l2_err      ssim   gw_ssim  masked_rel_l2_err  \
# 0        FBP-ramp    0.758821  0.212988  0.772632           0.548216
# 1        FBP-Hann    0.391061  0.335670  0.842706           0.329601
# 2  SIAC(FBP-ramp)    0.493628  0.508915  0.595342           0.485627
#
#    gradient_error
# 0        1.376708
# 1        0.715962
# 2        0.867811

# %% [markdown]
# ### Testing more SIAC parameters

# %%
ps = [1, 3]
moments = [0, 2, 4, 6]
BSorders = [1, 2, 3, 4, 5, 6, 7, 8, 9]

cases = {
    "FBP-ramp": {
        "image": fbp_ramp.asarray(),
        "extra": {"method": "FBP", "filter": "ramp"},
    },
    "FBP-Hann": {
        "image": fbp_hann.asarray(),
        "reference": fbp_ramp.asarray(),
        "extra": {"method": "FBP", "filter": "hann"},
    },
}

for p in ps:
    dg = nodal_image_to_dg(recon=fbp_ramp, xlim=xlim, ylim=ylim, p=p)

    for r in moments:
        # admissible SIAC reproduction for DG degree p
        if r > 2*p:
            continue
        for n in BSorders:

            Ustar = apply_siac_modal_dg_2d(dg=dg, moments=r, BSorder=n)

            name = f"DG-SIAC p{p} r{r+1} n{n}"

            cases[name] = {
                "image": Ustar,
                "reference": fbp_ramp.asarray(),
                "extra": {
                    "method": "DG-SIAC",
                    "filter": "ramp",
                    "p": p,
                    "moments": r+1,
                    "BSorder": n,
                },
            }
                  
            
df = build_metrics_table(
    cases,
    truth=phantom_np,
    dx=dx,
    dy=dy,
    hf_frac=0.6,
    data_range=1.0,
    compute_reference_metrics=False, 
    mask_keep_largest=False     # False if not shepp_logan
)

df
# Out:
#                 name  rel_l2_err      ssim   gw_ssim  masked_rel_l2_err  \
# 0           FBP-ramp    0.758821  0.212988  0.772632           0.548216
# 1           FBP-Hann    0.391061  0.335670  0.842706           0.329601
# 2   DG-SIAC p1 r1 n1    0.405589  0.335888  0.818874           0.354290
# 3   DG-SIAC p1 r1 n2    0.393434  0.406510  0.786823           0.369547
# 4   DG-SIAC p1 r1 n3    0.411634  0.465061  0.741036           0.398768
# 5   DG-SIAC p1 r1 n4    0.431312  0.506393  0.699390           0.422844
# 6   DG-SIAC p1 r1 n5    0.449786  0.535065  0.661020           0.443283
# 7   DG-SIAC p1 r1 n6    0.466139  0.554480  0.626365           0.460456
# 8   DG-SIAC p1 r1 n7    0.480581  0.567355  0.594979           0.475126
# 9   DG-SIAC p1 r1 n8    0.493371  0.575646  0.566502           0.487815
# 10  DG-SIAC p1 r1 n9    0.504771  0.580716  0.540578           0.498924
# 11  DG-SIAC p1 r3 n1    0.428359  0.309930  0.830426           0.357127
# 12  DG-SIAC p1 r3 n2    0.394899  0.352002  0.825638           0.349714
# 13  DG-SIAC p1 r3 n3    0.391970  0.389169  0.806426           0.362198
# 14  DG-SIAC p1 r3 n4    0.396277  0.419804  0.787912           0.374787
# 15  DG-SIAC p1 r3 n5    0.403965  0.445811  0.768828           0.387687
# 16  DG-SIAC p1 r3 n6    0.412567  0.467860  0.750223           0.399729
# 17  DG-SIAC p1 r3 n7    0.421394  0.486557  0.732100           0.410921
# 18  DG-SIAC p1 r3 n8    0.430061  0.502393  0.714565           0.421247
# 19  DG-SIAC p1 r3 n9    0.438415  0.515787  0.697637           0.430772
# 20  DG-SIAC p3 r1 n1    0.473666  0.426707  0.637986           0.461732
# 21  DG-SIAC p3 r1 n2    0.504670  0.553841  0.544437           0.498270
# 22  DG-SIAC p3 r1 n3    0.541599  0.564576  0.456335           0.533625
# 23  DG-SIAC p3 r1 n4    0.566382  0.561499  0.395299           0.556446
# 24  DG-SIAC p3 r1 n5    0.585369  0.553884  0.348672           0.573668
# 25  DG-SIAC p3 r1 n6    0.600310  0.545207  0.312483           0.587093
# 26  DG-SIAC p3 r1 n7    0.612502  0.536508  0.283583           0.597998
# 27  DG-SIAC p3 r1 n8    0.622698  0.528185  0.260036           0.607097
# 28  DG-SIAC p3 r1 n9    0.631399  0.520353  0.240505           0.614858
# 29  DG-SIAC p3 r3 n1    0.465018  0.391365  0.678654           0.447791
# 30  DG-SIAC p3 r3 n2    0.471561  0.517623  0.632002           0.464442
# 31  DG-SIAC p3 r3 n3    0.500347  0.540950  0.567356           0.493678
# 32  DG-SIAC p3 r3 n4    0.519920  0.551499  0.520172           0.512510
# 33  DG-SIAC p3 r3 n5    0.536193  0.555101  0.480050           0.527772
# 34  DG-SIAC p3 r3 n6    0.549637  0.555177  0.446220           0.540138
# 35  DG-SIAC p3 r3 n7    0.561107  0.553199  0.417061           0.550552
# 36  DG-SIAC p3 r3 n8    0.571040  0.550100  0.391698           0.559483
# 37  DG-SIAC p3 r3 n9    0.579765  0.546391  0.369434           0.567274
# 38  DG-SIAC p3 r5 n1    0.464574  0.378183  0.689382           0.444699
# 39  DG-SIAC p3 r5 n2    0.461892  0.494799  0.659848           0.453337
# 40  DG-SIAC p3 r5 n3    0.486453  0.515191  0.607048           0.479083
# 41  DG-SIAC p3 r5 n4    0.502458  0.526236  0.569647           0.494980
# 42  DG-SIAC p3 r5 n5    0.516238  0.532016  0.536743           0.508292
# 43  DG-SIAC p3 r5 n6    0.527811  0.534923  0.508297           0.519235
# 44  DG-SIAC p3 r5 n7    0.537909  0.535693  0.482994           0.528639
# 45  DG-SIAC p3 r5 n8    0.546829  0.534967  0.460306           0.536844
# 46  DG-SIAC p3 r5 n9    0.554810  0.533214  0.439791           0.544115
# 47  DG-SIAC p3 r7 n1    0.464910  0.371522  0.694144           0.443517
# 48  DG-SIAC p3 r7 n2    0.457628  0.481908  0.673120           0.447984
# 49  DG-SIAC p3 r7 n3    0.479854  0.499211  0.626799           0.471673
# 50  DG-SIAC p3 r7 n4    0.493628  0.508915  0.595342           0.485627
# 51  DG-SIAC p3 r7 n5    0.505673  0.514531  0.567347           0.497497
# 52  DG-SIAC p3 r7 n6    0.515806  0.518176  0.543034           0.507276
# 53  DG-SIAC p3 r7 n7    0.524743  0.520239  0.521128           0.515769
# 54  DG-SIAC p3 r7 n8    0.532719  0.521064  0.501215           0.523254
# 55  DG-SIAC p3 r7 n9    0.539935  0.520883  0.482934           0.529954
#
#     gradient_error   method filter    p  moments  BSorder
# 0         1.376708      FBP   ramp  NaN      NaN      NaN
# 1         0.715962      FBP   hann  NaN      NaN      NaN
# 2         0.743229  DG-SIAC   ramp  1.0      1.0      1.0
# 3         0.704817  DG-SIAC   ramp  1.0      1.0      2.0
# 4         0.733397  DG-SIAC   ramp  1.0      1.0      3.0
# 5         0.764917  DG-SIAC   ramp  1.0      1.0      4.0
# 6         0.793032  DG-SIAC   ramp  1.0      1.0      5.0
# 7         0.816379  DG-SIAC   ramp  1.0      1.0      6.0
# 8         0.835744  DG-SIAC   ramp  1.0      1.0      7.0
# 9         0.851894  DG-SIAC   ramp  1.0      1.0      8.0
# 10        0.865495  DG-SIAC   ramp  1.0      1.0      9.0
# 11        0.800925  DG-SIAC   ramp  1.0      3.0      1.0
# 12        0.717704  DG-SIAC   ramp  1.0      3.0      2.0
# 13        0.705913  DG-SIAC   ramp  1.0      3.0      3.0
# 14        0.712880  DG-SIAC   ramp  1.0      3.0      4.0
# 15        0.727235  DG-SIAC   ramp  1.0      3.0      5.0
# 16        0.743084  DG-SIAC   ramp  1.0      3.0      6.0
# 17        0.758791  DG-SIAC   ramp  1.0      3.0      7.0
# 18        0.773599  DG-SIAC   ramp  1.0      3.0      8.0
# 19        0.787288  DG-SIAC   ramp  1.0      3.0      9.0
# 20        0.831856  DG-SIAC   ramp  3.0      1.0      1.0
# 21        0.866665  DG-SIAC   ramp  3.0      1.0      2.0
# 22        0.905593  DG-SIAC   ramp  3.0      1.0      3.0
# 23        0.926986  DG-SIAC   ramp  3.0      1.0      4.0
# 24        0.941345  DG-SIAC   ramp  3.0      1.0      5.0
# 25        0.951310  DG-SIAC   ramp  3.0      1.0      6.0
# 26        0.958608  DG-SIAC   ramp  3.0      1.0      7.0
# 27        0.964136  DG-SIAC   ramp  3.0      1.0      8.0
# 28        0.968448  DG-SIAC   ramp  3.0      1.0      9.0
# 29        0.824272  DG-SIAC   ramp  3.0      3.0      1.0
# 30        0.834724  DG-SIAC   ramp  3.0      3.0      2.0
# 31        0.871587  DG-SIAC   ramp  3.0      3.0      3.0
# 32        0.892930  DG-SIAC   ramp  3.0      3.0      4.0
# 33        0.908931  DG-SIAC   ramp  3.0      3.0      5.0
# 34        0.920907  DG-SIAC   ramp  3.0      3.0      6.0
# 35        0.930305  DG-SIAC   ramp  3.0      3.0      7.0
# 36        0.937843  DG-SIAC   ramp  3.0      3.0      8.0
# 37        0.944018  DG-SIAC   ramp  3.0      3.0      9.0
# 38        0.824165  DG-SIAC   ramp  3.0      5.0      1.0
# 39        0.823645  DG-SIAC   ramp  3.0      5.0      2.0
# 40        0.857541  DG-SIAC   ramp  3.0      5.0      3.0
# 41        0.876823  DG-SIAC   ramp  3.0      5.0      4.0
# 42        0.891981  DG-SIAC   ramp  3.0      5.0      5.0
# 43        0.903672  DG-SIAC   ramp  3.0      5.0      6.0
# 44        0.913175  DG-SIAC   ramp  3.0      5.0      7.0
# 45        0.921043  DG-SIAC   ramp  3.0      5.0      8.0
# 46        0.927680  DG-SIAC   ramp  3.0      5.0      9.0
# 47        0.824773  DG-SIAC   ramp  3.0      7.0      1.0
# 48        0.818398  DG-SIAC   ramp  3.0      7.0      2.0
# 49        0.850260  DG-SIAC   ramp  3.0      7.0      3.0
# 50        0.867811  DG-SIAC   ramp  3.0      7.0      4.0
# 51        0.881919  DG-SIAC   ramp  3.0      7.0      5.0
# 52        0.892915  DG-SIAC   ramp  3.0      7.0      6.0
# 53        0.902020  DG-SIAC   ramp  3.0      7.0      7.0
# 54        0.909694  DG-SIAC   ramp  3.0      7.0      8.0
# 55        0.916286  DG-SIAC   ramp  3.0      7.0      9.0

# %% [markdown]
# ### Heatmaps

# %%
metrics = ["gw_ssim", "masked_rel_l2_err"]

for p in ps:
    for metric in metrics:
        cmap = "viridis_r" if metric != "gw_ssim" else "viridis"
        plot_param_heatmap_single_run(
            df,
            method="DG-SIAC",
            metric=metric,
            p=p,
            cmap=cmap,  # reverse for masked L2 error
            save_name=f"dg_siac_param_heatmap_p{p}_{metric}",
            minimize=(metric != "gw_ssim")  # maximize GWSSIM
        )
        plot_param_heatmap_single_run(
            df,
            method="DG-SIAC",
            metric=metric,
            p=p,
            cmap=cmap,  # reverse for masked L2 error
            title=f"Nodal-to-modal, p={p}: {metric}",
            minimize=(metric != "gw_ssim")  # maximize GWSSIM
        )

# %%
# best_by_method = (
#     df.sort_values("truth_rel_l2_err")
#       .groupby("method", as_index=False)
#       .first()
# )

df_dg = df[df["method"] == "DG-SIAC"].copy()

best_l2_row = df_dg.loc[df_dg["rel_l2_err"].idxmin()]
best_masked_l2_row = df_dg.loc[df_dg["masked_rel_l2_err"].idxmin()]
best_gwssim_row = df_dg.loc[df_dg["gw_ssim"].idxmax()]
best_ssim_row = df_dg.loc[df_dg["ssim"].idxmax()]

summary_rows = []

# Baselines
summary_rows.append(df.loc[df["name"] == "FBP-ramp"].iloc[0])
summary_rows.append(df.loc[df["name"] == "FBP-Hann"].iloc[0])

# Best DG-SIAC rows
summary_rows.append(best_l2_row)
summary_rows.append(best_masked_l2_row)
summary_rows.append(best_gwssim_row)
summary_rows.append(best_ssim_row)

df_summary = pd.DataFrame(summary_rows).copy()

df_summary["selected_as"] = [
    "baseline",
    "baseline",
    "best SIAC rel_l2",
    "best SIAC masked_rel_l2",
    "best SIAC gw_ssim",
    "best SIAC ssim",
]

cols = ["selected_as"] + [c for c in df_summary.columns if c != "selected_as"]
df_summary = df_summary[cols]

df_summary
# Out:
#                 selected_as              name  rel_l2_err      ssim   gw_ssim  \
# 0                  baseline          FBP-ramp    0.758821  0.212988  0.772632
# 1                  baseline          FBP-Hann    0.391061  0.335670  0.842706
# 13         best SIAC rel_l2  DG-SIAC p1 r3 n3    0.391970  0.389169  0.806426
# 12  best SIAC masked_rel_l2  DG-SIAC p1 r3 n2    0.394899  0.352002  0.825638
# 11        best SIAC gw_ssim  DG-SIAC p1 r3 n1    0.428359  0.309930  0.830426
# 10           best SIAC ssim  DG-SIAC p1 r1 n9    0.504771  0.580716  0.540578
#
#     masked_rel_l2_err  gradient_error   method filter    p  moments  BSorder
# 0            0.548216        1.376708      FBP   ramp  NaN      NaN      NaN
# 1            0.329601        0.715962      FBP   hann  NaN      NaN      NaN
# 13           0.362198        0.705913  DG-SIAC   ramp  1.0      3.0      3.0
# 12           0.349714        0.717704  DG-SIAC   ramp  1.0      3.0      2.0
# 11           0.357127        0.800925  DG-SIAC   ramp  1.0      3.0      1.0
# 10           0.498924        0.865495  DG-SIAC   ramp  1.0      1.0      9.0

# %% [markdown]
# From this table, and the consequent plots below, we can conclude that a low polynomial degree, combined with a low moment conservation and low smoothness seems best.

# %%
best_l2_name = best_l2_row["name"]
best_masked_l2_name = best_masked_l2_row["name"]
best_gwssim_name = best_gwssim_row["name"]
best_ssim_name = best_ssim_row["name"]

img_best_l2 = cases[best_l2_name]["image"]
img_best_masked_l2 = cases[best_masked_l2_name]["image"]
img_best_gwssim = cases[best_gwssim_name]["image"]
img_best_ssim = cases[best_ssim_name]["image"]

plot_img(img=fbp_hann, title="FBP (Hann)")
plot_img(
    img=img_best_masked_l2,
    title=f"Best DG-SIAC by masked rel L2\n(p={best_masked_l2_row['p']}, r+1={best_masked_l2_row['moments']}, n={best_masked_l2_row['BSorder']})"
)
plot_img(
    img=img_best_gwssim,
    title=f"Best DG-SIAC by GW-SSIM\n(p={best_gwssim_row['p']}, r+1={best_gwssim_row['moments']}, n={best_gwssim_row['BSorder']})"
)
plot_img(
    img=img_best_l2,
    title=f"Best DG-SIAC by rel L2\n(p={best_l2_row['p']}, r+1={best_l2_row['moments']}, n={best_l2_row['BSorder']})"
)
  
plot_img(
    img=img_best_ssim,
    title=f"Best DG-SIAC by SSIM\n(p={best_ssim_row['p']}, r+1={best_ssim_row['moments']}, n={best_ssim_row['BSorder']})"
)

plot_img_zoom(img=fbp_hann, title="FBP (Hann) (zoom)")
plot_img_zoom(
    img=img_best_masked_l2,
    title=f"Best DG-SIAC by masked rel L2 (zoom) \n(p={best_masked_l2_row['p']}, r+1={best_masked_l2_row['moments']}, n={best_masked_l2_row['BSorder']})"
)

plot_img_zoom(
    img=img_best_gwssim,
    title=f"Best DG-SIAC by GW-SSIM (zoom)\n(p={best_gwssim_row['p']}, r+1={best_gwssim_row['moments']}, n={best_gwssim_row['BSorder']})"
)
plot_img_zoom(
    img=img_best_l2,
    title=f"Best DG-SIAC by rel L2 (zoom)\n(p={best_l2_row['p']}, r+1={best_l2_row['moments']}, n={best_l2_row['BSorder']})"
)

plot_img_zoom(
    img=img_best_ssim,
    title=f"Best DG-SIAC by SSIM (zoom)\n(p={best_ssim_row['p']}, r+1={best_ssim_row['moments']}, n={best_ssim_row['BSorder']})"
)
# Out:
# (<Figure size 500x500 with 1 Axes>,
#  <Axes: title={'center': 'Best DG-SIAC by SSIM (zoom)\n(p=1.0, r+1=1.0, n=9.0)'}>)

# %% [markdown]
# ### Plotting the SSIM mapsand Phantom masks for visual

# %%
from src.metrics import gradient_weighted_ssim, phantom_support_mask
gw, ssim_map, wmap = gradient_weighted_ssim(
    phantom_np, Ustar, alpha=0.75, sigma=1.0,
    return_maps=True
    )
print("Gradient-weighted SSIM:", gw)

plt.figure()
plt.imshow(ssim_map, cmap="gray")
# plt.title("SSIM map")
# plt.colorbar()
plt.axis("off")
plt.savefig(f"figures/SSIM_map_{phantom_name}.pdf", dpi=300, bbox_inches="tight", pad_inches=0)
plt.show()

plt.figure()
plt.imshow(wmap, cmap="gray")
# plt.title("Gradient weight map")
# plt.colorbar()
plt.axis("off")
plt.savefig(f"figures/GWSSIM_map_{phantom_name}.pdf", dpi=300, bbox_inches="tight", pad_inches=0)
plt.show()

mask = phantom_support_mask(phantom_np, tau=1e-8, pad_pixels=2, keep_largest=False)

plt.figure()
plt.imshow(phantom_np, cmap="gray")
plt.contour(mask, colors="red", linewidths=1)
# plt.title("Mask overlay on phantom")
plt.axis("off")
plt.savefig(f"figures/relative_l2_mask_{phantom_name}.pdf", dpi=300, bbox_inches="tight", pad_inches=0)
plt.show()
# Out:
# Gradient-weighted SSIM: 0.4687543729149176

# %% [markdown]
# ### 1D Slice Comparison

# %%
# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------

# Parameter configurations to compare
# Note: moments = r according to the current convention
# configs = [
#     {"p": 1, "r+1": 1, "n": 2, "label": r"SIAC $p=1,\ r+1=1,\ n=2$", "color": "tab:blue"},
#     {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
#     {"p": 1, "r+1": 3, "n": 6, "label": r"SIAC $p=1,\ r+1=3,\ n=6$", "color": "tab:purple"},
#     {"p": 3, "r+1": 3, "n": 2, "label": r"SIAC $p=3,\ r+1=3,\ n=2$", "color": "tab:brown"},
# ]
# configs = [
#     {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=1,\ n=2$", "color": "tab:blue"},
#     {"p": 1, "r+1": 5, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
#     {"p": 3, "r+1": 5, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=6$", "color": "tab:purple"},
#     {"p": 3, "r+1": 7, "n": 3, "label": r"SIAC $p=3,\ r+1=3,\ n=2$", "color": "tab:brown"},
# ]

# configs = [
#     {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3\ n=2$", "color": "tab:blue"},
# ]
configs = [
    # {"p": 1, "r+1": 1, "n": 2, "label": r"SIAC $p=1,\ r+1=1,\ n=2$", "color": "tab:blue"},
    {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
    # {"p": 1, "r+1": 5, "n": 2, "label": r"SIAC $p=1,\ r+1=5,\ n=2$", "color": "tab:cyan"},
    {"p": 3, "r+1": 7, "n": 4, "label": r"SIAC $p=3,\ r+1=7,\ n=4$", "color": "tab:cyan"},
]
# Central horizontal slice index
slice_idx = phantom_np.shape[0] // 2

# Optional x-axis: use physical coordinates if xlim is available
x = np.linspace(xlim[0], xlim[1], phantom_np.shape[1])

# ------------------------------------------------------------
# Compute SIAC reconstructions and collect slices
# ------------------------------------------------------------

slice_data = []

# Reference phantom
slice_data.append({
    "y": phantom_np[slice_idx, :],
    "label": "Ground truth",
    "linewidth": 2.5,
    "linestyle": "-",
    "color": "black"
})

# Standard FBP references
fbp_ramp_np = _to_numpy(fbp_ramp)
slice_data.append({
    "y": fbp_ramp_np[slice_idx, :],
    "label": "Ram--Lak",
    "linewidth": 1.5,
    "linestyle": "--", 
    "color": "tab:orange"
})

fbp_hann_np = _to_numpy(fbp_hann)
slice_data.append({
    "y": fbp_hann_np[slice_idx, :],
    "label": "Hann",
    "linewidth": 1.5,
    "linestyle": "--", 
    "color": "tab:green"
})

# SIAC configurations
for cfg in configs:
    p = cfg["p"]
    r = cfg["r+1"]
    n = cfg["n"]

    # implementation uses moments = r - 1
    moments = r - 1
    BSorder = n

    dg = nodal_image_to_dg(
        recon=fbp_ramp,
        xlim=xlim,
        ylim=ylim,
        p=p
    )

    Ustar = apply_siac_modal_dg_2d(
        dg=dg,
        moments=moments,
        BSorder=BSorder
    )

    slice_data.append({
        "y": Ustar[slice_idx, :],
        "label": cfg["label"],
        "linewidth": 1.6,
        "linestyle": "-", 
        "color": cfg["color"]
    })

# ------------------------------------------------------------
# Plot slice comparison
# ------------------------------------------------------------

plt.figure(figsize=(8, 4.8))

for item in slice_data:
    plt.plot(
        x,
        item["y"],
        label=item["label"],
        linewidth=item["linewidth"],
        linestyle=item["linestyle"], 
        color=item["color"]
    )

plt.xlabel(r"$x$")
plt.ylabel("Intensity")
#plt.title("Central horizontal slice comparison")
plt.grid(True, alpha=0.3)
plt.legend(fontsize=9, loc="best")
plt.tight_layout()

plt.savefig(f"figures/{phantom_name}_nodal_to_modal_slice_comparison.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Beyond the Scope: Feeding the DG-SIAC code the Hann windowed FBP

# %%
# Admissible degrees: 0, 1, 3, 4, 9 (if wrong, will be internally fixed by nodal_image_to_dg
p = 1
order = p + 1

# Postprocessor
moments = 2
BSorder = 2

# nodal interpretation: nodal --> modal transform
dg = nodal_image_to_dg(recon=fbp_hann, xlim=xlim, ylim=ylim, p=p)

# immediate evaluation
U = eval_dg_on_img_grid(dg=dg)

# Postprocessor
Ustar = apply_siac_modal_dg_2d(dg=dg, moments=moments, BSorder=BSorder)
plot_img(img=fbp_hann, title=f"FBP (Hann)")
# plot_img(img=U, title=f"DG evaluation (p={p})")
plot_img(img=Ustar, title=f"SIAC evaluation (r={moments+1}, n={BSorder})")
plot_img(img=phantom, title="Original Phantom")

plot_img_zoom(img=fbp_hann, title=f"FBP (Hann) (zoom)")
# plot_img_zoom(img=U, title=f"DG evaluation (p={p}) (zoom)")
plot_img_zoom(img=Ustar, title=f"SIAC evaluation (r={moments+1}, n={BSorder}) (zoom)")
plot_img_zoom(img=phantom, title="Original Phantom (zoom)")

cases = {
    "FBP-ramp": {
        "image": fbp_ramp.asarray(),
    },
    "FBP-Hann": {
        "image": fbp_hann.asarray(),
        "reference": fbp_ramp.asarray(),
    },
    "SIAC(FBP-Hann)": {
        "image": Ustar,
        "reference": fbp_ramp.asarray(),
    },
}
dx, dy = space.cell_sides


df = build_metrics_table(
    cases,
    truth=phantom_np,
    dx=dx,
    dy=dy,
    hf_frac=0.6,
    data_range=1.0,
    compute_reference_metrics=False, 
    mask_keep_largest=False     # False if not shepp_logan
)

df
# Out:
#              name  rel_l2_err      ssim   gw_ssim  masked_rel_l2_err  \
# 0        FBP-ramp    0.758821  0.212988  0.772632           0.548216
# 1        FBP-Hann    0.391061  0.335670  0.842706           0.329601
# 2  SIAC(FBP-Hann)    0.376904  0.446147  0.806922           0.356964
#
#    gradient_error
# 0        1.376708
# 1        0.715962
# 2        0.681070

# %%
# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------

# Parameter configurations to compare
# Note: moments = r according to the current convention
configs = [
    {"p": 1, "r+1": 1, "n": 2, "label": r"SIAC $p=1,\ r+1=1,\ n=2$", "color": "tab:blue"},
    {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
    {"p": 1, "r+1": 5, "n": 2, "label": r"SIAC $p=1,\ r+1=5,\ n=2$", "color": "tab:purple"},
    {"p": 3, "r+1": 3, "n": 2, "label": r"SIAC $p=3,\ r+1=3,\ n=2$", "color": "tab:brown"},
]
# configs = [
#     {"p": 1, "r+1": 5, "n": 1, "label": r"SIAC $p=1,\ r+1=5,\ n=1$", "color": "tab:cyan"},
# ]

# configs = [
#     {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
#     {"p": 3, "r+1": 7, "n": 4, "label": r"SIAC $p=3,\ r+1=7,\ n=4$", "color": "indigo"},
# ]

# Central horizontal slice index
slice_idx = phantom_np.shape[0] // 2

# Optional x-axis: use physical coordinates if xlim is available
x = np.linspace(xlim[0], xlim[1], phantom_np.shape[1])

# ------------------------------------------------------------
# Compute SIAC reconstructions and collect slices
# ------------------------------------------------------------

slice_data = []

# Reference phantom
slice_data.append({
    "y": phantom_np[slice_idx, :],
    "label": "Ground truth",
    "linewidth": 2.5,
    "linestyle": "-",
    "color": "black"
})

# Standard FBP references
fbp_ramp_np = _to_numpy(fbp_ramp)
slice_data.append({
    "y": fbp_ramp_np[slice_idx, :],
    "label": "Ram--Lak",
    "linewidth": 1.5,
    "linestyle": "--", 
    "color": "tab:orange"
})

fbp_hann_np = _to_numpy(fbp_hann)
slice_data.append({
    "y": fbp_hann_np[slice_idx, :],
    "label": "Hann",
    "linewidth": 1.5,
    "linestyle": "--", 
    "color": "tab:green"
})

# SIAC configurations
for cfg in configs:
    p = cfg["p"]
    rp1 = cfg["r+1"]
    n = cfg["n"]

    # implementation uses moments = rp1 - 1
    moments = rp1 - 1
    BSorder = n

    dg = nodal_image_to_dg(
        recon=fbp_hann,
        xlim=xlim,
        ylim=ylim,
        p=p
    )

    Ustar = apply_siac_modal_dg_2d(
        dg=dg,
        moments=moments,
        BSorder=BSorder
    )

    slice_data.append({
        "y": Ustar[slice_idx, :],
        "label": cfg["label"],
        "linewidth": 1.6,
        "linestyle": "-", 
        "color": cfg["color"]
    })

# ------------------------------------------------------------
# Plot slice comparison
# ------------------------------------------------------------

plt.figure(figsize=(8, 4.8))

for item in slice_data:
    plt.plot(
        x,
        item["y"],
        label=item["label"],
        linewidth=item["linewidth"],
        linestyle=item["linestyle"], 
        color=item["color"]
    )

plt.xlabel(r"$x$")
plt.ylabel("Intensity")
#plt.title("Central horizontal slice comparison")
plt.grid(True, alpha=0.3)
plt.legend(fontsize=9, loc="best")
plt.tight_layout()

plt.savefig(f"figures/{phantom_name}_nodal_to_modal_slice_comparison.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Error Visualisation pointwise: 1D slices and 2D

# %%
# ------------------------------------------------------------
# Configuration
# ------------------------------------------------------------

# configs = [
#     {"p": 1, "r+1": 1, "n": 2, "label": r"SIAC $p=1,\ r+1=1,\ n=2$", "color": "tab:blue"},
#     {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
#     {"p": 1, "r+1": 5, "n": 2, "label": r"SIAC $p=1,\ r+1=5,\ n=2$", "color": "tab:purple"},
#     {"p": 3, "r+1": 3, "n": 2, "label": r"SIAC $p=3,\ r+1=3,\ n=2$", "color": "tab:brown"},
# ]
# configs = [
#     {"p": 1, "r+1": 3, "n": 2, "label": r"SIAC $p=1,\ r+1=3,\ n=2$", "color": "tab:red"},
#     {"p": 3, "r+1": 7, "n": 4, "label": r"SIAC $p=3,\ r+1=7,\ n=4$", "color": "indigo"},
# ]
configs = [
    {"p": 1, "r+1": 5, "n": 1, "label": r"SIAC $p=1,\ r+1=5,\ n=1$", "color": "tab:cyan"},
]

# Central horizontal slice index
slice_idx = phantom_np.shape[0] // 2

# Physical x-axis
x = np.linspace(xlim[0], xlim[1], phantom_np.shape[1])

# ------------------------------------------------------------
# Compute reconstructions and collect full 2D data
# ------------------------------------------------------------

solution_data = []

# Standard FBP references
fbp_ramp_np = _to_numpy(fbp_ramp)
solution_data.append({
    "U": fbp_ramp_np,
    "label": "Ram--Lak",
    "linewidth": 1.5,
    "linestyle": "--",
    "color": "tab:orange"
})

fbp_hann_np = _to_numpy(fbp_hann)
solution_data.append({
    "U": fbp_hann_np,
    "label": "Hann",
    "linewidth": 1.5,
    "linestyle": "--",
    "color": "tab:green"
})

# SIAC configurations
for cfg in configs:
    p = cfg["p"]
    rp1 = cfg["r+1"]
    n = cfg["n"]

    # implementation uses moments = rp1 - 1
    moments = rp1 - 1
    BSorder = n

    dg = nodal_image_to_dg(
        recon=fbp_hann,
        xlim=xlim,
        ylim=ylim,
        p=p
    )

    Ustar = apply_siac_modal_dg_2d(
        dg=dg,
        moments=moments,
        BSorder=BSorder
    )

    solution_data.append({
        "U": Ustar,
        "label": cfg["label"],
        "linewidth": 1.6,
        "linestyle": "-",
        "color": cfg["color"]
    })

# ------------------------------------------------------------
# Compute pointwise errors
# ------------------------------------------------------------

error_data = []

for item in solution_data:
    E = item["U"] - phantom_np

    error_data.append({
        "E": E,
        "slice_error": E[slice_idx, :],
        "label": item["label"],
        "linewidth": item["linewidth"],
        "linestyle": item["linestyle"],
        "color": item["color"],
        "max_abs_error": np.max(np.abs(E))
    })
# ------------------------------------------------------------
# Print full-image and slice max errors
# ------------------------------------------------------------

print(f"{'Method':<35s} {'Max 2D error':>15s} {'Max slice error':>18s}")
print("-" * 72)

for item in error_data:
    max_2d_error = np.max(np.abs(item["E"]))
    max_slice_error = np.max(np.abs(item["slice_error"]))

    print(
        f"{item['label']:<35s} "
        f"{max_2d_error:>15.6e} "
        f"{max_slice_error:>18.6e}"
    )
# Out:
# Method                                 Max 2D error    Max slice error
# ------------------------------------------------------------------------
# Ram--Lak                               8.194377e-01       4.839346e-01
# Hann                                   5.190515e-01       4.656838e-01
# SIAC $p=1,\ r+1=5,\ n=1$               6.017086e-01       5.012098e-01

# %%
# ------------------------------------------------------------
# Plot 1D central slice pointwise errors
# ------------------------------------------------------------

plt.figure(figsize=(8, 4.8))

for item in error_data:
    plt.plot(
        x,
        item["slice_error"],
        label=item["label"],
        linewidth=item["linewidth"],
        linestyle=item["linestyle"],
        color=item["color"]
    )

plt.axhline(0.0, color="black", linewidth=0.8)
plt.xlabel(r"$x$")
plt.ylabel(r"Pointwise error")
plt.grid(True, alpha=0.3)
plt.legend(fontsize=9, loc="best")
plt.tight_layout()

plt.savefig(
    f"figures/{phantom_name}_nodal_to_modal_slice_pointwise_error.pdf",
    bbox_inches="tight"
)
plt.show()

# %%
# ------------------------------------------------------------
# Plot 2D pointwise error images
# ------------------------------------------------------------

n_methods = len(error_data)

# Use shared symmetric color scale
vmax = max(item["max_abs_error"] for item in error_data)
vmin = -vmax

ncols = 3
nrows = int(np.ceil(n_methods / ncols))

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(4.2 * ncols, 4.0 * nrows),
    constrained_layout=True
)

axes = np.asarray(axes).ravel()

for ax, item in zip(axes, error_data):
    im = ax.imshow(
        item["E"],
        extent=[xlim[0], xlim[1], ylim[0], ylim[1]],
        origin="lower",
        cmap="seismic",
        vmin=vmin,
        vmax=vmax
    )

    ax.set_title(item["label"], fontsize=10)
    ax.set_xlabel(r"$x$")
    ax.set_ylabel(r"$y$")

# Hide unused axes
for ax in axes[len(error_data):]:
    ax.axis("off")

fig.colorbar(
    im,
    ax=axes[:len(error_data)],
    shrink=0.85,
    label=r"Pointwise error"
)

plt.savefig(
    f"figures/{phantom_name}_nodal_to_modal_2d_pointwise_error.pdf",
    bbox_inches="tight"
)
plt.show()
